# %% [markdown]
# # SqueezeNet End-to-End Object Detection
#
# ConvDet is the layer that performs the object detection, outputting bounding boxes as well as the classification scores.

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import transforms
import argparse
import os

# %%
from utils.boxes import generate_anchors, xyxy_to_xywh, xywh_to_xyxy
from utils.boxes import compute_deltas, compute_overlaps, boxes_postprocess

# %%
from model.resolver import deltas_to_boxes, compute_overlaps, safe_softmax

# %%
from utils.config import Args

# %%
# %tb
args = Args().parse()
# Out:
# trainig chunk_size: [15]
# The result will be saved to C:\Users\CATHX\repos\SqueezeDetect\SqueezeDet-PyTorch\exp\default
# No traceback available to show.

# %%
torch.cuda.get_device_name(0)
# Out:
# 'GeForce RTX 2070 with Max-Q Design'

# %% [markdown]
# The fire module, in the forward function, is already concatenating the 1x1 and 3x3 expand layers. If we call on the Fire function or squeezenet, we should be able to use it.
# In the github repo, they said that the final layer input is innitialized weirdly so now, I have to figure out how they do it.

# %%
torch.cuda.empty_cache()

# %%
# torch.cuda.memory_summary(device=None, abbreviated=False)

# %%
args = Args().parse()
# Out:
# trainig chunk_size: [15]
# The result will be saved to C:\Users\CATHX\repos\SqueezeDetect\SqueezeDet-PyTorch\exp\default

# %%
# !pip install imutils
# Out:
# Requirement already satisfied: imutils in c:\programdata\anaconda3\lib\site-packages (0.5.3)

# %%
#  from demo import demo

args.arch = 'squeezedet'
args.gpus = 0
args.device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
# args.device = 'c'
args.root_dir = ''
args.batch_size = 16
args.num_epochs = 150
args.no_eval = False

args.load_model = 'C:/users/cathx/repos/SqueezeDetect/SqueezeDet-PyTorch/src/utils/squeezedet_kitti_epoch280.pth'

# %%
from eval import eval
# Out:
# Hello Tesla! I am images
# Hello Tesla! I am detective Squee
# Hello Tesla! I am loaded model.
# Hello Tesla! I am Trainer
# Hello Tesla!

# %%
eval(args)
# Out:
# HEllo Tesla! I am kitti_class
# anchors                        [[   8.    8.   34.   30.]
#  [   8.    8.   75.   45.]
#  [   8.    8.   38.   90.]
#  ...
#  [1240.  376.  194.  178.]
#  [1240.  376.  283.  156.]
#  [1240.  376.  381.  185.]]
# anchors_per_grid               9
# arch                           squeezedet
# batch_size                     16
# bbox_loss_weight               6.0
# chunk_sizes                    [15]
# class_loss_weight              1.0
# class_names                    ('Car', 'Pedestrian', 'Cyclist')
# data_dir                       C:\Users\CATHX\repos\SqueezeDetect\SqueezeDet-PyTorch\data
# dataset                        kitti
# debug                          2
# debug_dir                      C:\Users\CATHX\repos\SqueezeDetect\SqueezeDet-PyTorch\exp\default\debug
# device                         cuda:0
# drift_prob                     1.0
# dropout_prob                   0.5
# exp_dir                        C:\Users\CATHX\repos\SqueezeDetect\SqueezeDet-PyTorch\exp
# exp_id                         default
# flip_prob                      0.5
# forbid_resize                  False
# gpus                           -1
# gpus_str                       0
# grad_norm                      5.0
# input                          0
# input_size                     (384, 1248)
# keep_top_k                     64
# load_model                     C:/users/cathx/repos/SqueezeDetect/SqueezeDet-PyTorch/src/utils/squeezedet_kitti_epoch280.pth
# lr                             0.01
# master_batch_size              15
# mode                           None
# model                          None
# momentum                       0.9
# negative_score_loss_weight     100.0
# nms_thresh                     0.35
# no_eval                        False
# not_cuda_benchmark             False
# num_anchors                    16848
# num_classes                    3
# num_epochs                     150
# num_iters                      -1
# num_workers                    4
# output                         None
# output_dir                     C:\Users\CATHX\repos\SqueezeDetect\SqueezeDet-PyTorch\video
# positive_score_loss_weight     3.75
# print_interval                 10
# rgb_mean                       [[[93.877 98.801 95.923]]]
# rgb_std                        [[[78.782 80.13  81.2  ]]]
# root_dir
# save_dir                       C:\Users\CATHX\repos\SqueezeDetect\SqueezeDet-PyTorch\exp\default
# save_intervals                 1
# score_thresh                   0.3
# seed                           42
# val_intervals                  5
# weight_decay                   0.0001
# loaded model C:/users/cathx/repos/SqueezeDetect/SqueezeDet-PyTorch/src/utils/squeezedet_kitti_epoch280.pth, epoc 280
# Model successfully loaded.
# eval: [0/24] | data 6.267s | net2.864s
# eval: [10/24] | data 0.000s | net0.536s
# eval: [20/24] | data 0.000s | net0.527s
# Elapsed 0.35min (55.5ms/image, 18.0frames/s)
# --------------------------------------------------------------------------------
# [0.921084, 0.87216, 0.77248]
# [0.833907, 0.739172, 0.655501]
# [0.625842, 0.801492, 0.802135]
# Car_easy             0.921
# Car_moderate         0.872
# Car_hard             0.772
# Pedestrian_easy      0.834
# Pedestrian_moderate  0.739
# Pedestrian_hard      0.656
# Cyclist_easy         0.626
# Cyclist_moderate     0.801
# Cyclist_hard         0.802
# mAP                  0.780

# %%
args.device
# Out:
# 'cpu'

# %%
from train import train
# Out:
# Hello Tesla! I am Trainer
# Hello Tesla!

# %%
train(args)
# Out:
# anchors                        [[   8.    8.   34.   30.]
#  [   8.    8.   75.   45.]
#  [   8.    8.   38.   90.]
#  ...
#  [1240.  376.  194.  178.]
#  [1240.  376.  283.  156.]
#  [1240.  376.  381.  185.]]
# anchors_per_grid               9
# arch                           squeezedet
# batch_size                     16
# bbox_loss_weight               6.0
# chunk_sizes                    [20]
# class_loss_weight              1.0
# class_names                    ('Car', 'Pedestrian', 'Cyclist', 'Van', 'Truck')
# data_dir                       D:\squeezenet\data
# dataset                        kitti
# debug                          0
# debug_dir                      D:\squeezenet\exp\default\debug
# device                         cuda:0
# drift_prob                     1.0
# dropout_prob                   0.5
# exp_dir                        D:\squeezenet\exp
# exp_id                         default
# flip_prob                      0.5
# forbid_resize                  False
# gpus                           0
# gpus_str                       0
# grad_norm                      5.0
# input                          0
# input_size                     (384, 1248)
# keep_top_k                     64
# load_model
# lr                             0.01
# master_batch_size              20
# mode                           None
# model                          None
# momentum                       0.9
# negative_score_loss_weight     100.0
# nms_thresh                     0.4
# no_eval                        False
# not_cuda_benchmark             False
# num_anchors                    16848
# num_classes                    5
# num_epochs                     150
# num_iters                      -1
# num_workers                    4
# output                         None
# positive_score_loss_weight     3.75
# print_interval                 10
# rgb_mean                       [[[93.877 98.801 95.923]]]
# rgb_std                        [[[78.782 80.13  81.2  ]]]
# root_dir
# save_dir                       D:\squeezenet\exp\default
# save_intervals                 1
# score_thresh                   0.3
# seed                           42
# val_intervals                  5
# weight_decay                   0.0001
# D:\squeezenet\Tesloyta\utils\trainer.py:47: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   self.args.grad_norm)
# | data 5547.7ms | net 1739.1ms
# | data 0.0ms | net 549.9ms
# | data 0.0ms | net 567.1ms
# | data 15.6ms | net 538.7ms
# | data 0.0ms | net 548.2ms
# | data 0.0ms | net 566.0ms
# | data 0.0ms | net 551.3ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 548.7ms
# | data 0.0ms | net
# | data 0.0ms | net 599.3ms
# | data 587.8ms | net 605.7ms
# | data 78.1ms | net 633.2ms
# | data 0.0ms | net 595.9ms
# | data 926.0ms | net 676.0ms
# | data 2.0ms | net 589.7ms
# | data 927.8ms | net 612.2ms
# | data 2.0ms | net 587.5ms
# | data 912.0ms | net 611.7ms
# | data 1.0ms | net 561.0ms
# | data 203.1ms | net 563.4ms
# | data 0.0ms | net 547.9ms
# epoch 4:  train | loss 2.894 | class_loss 0.687 | score_loss 0.763 | bbox_loss 1.444 | epoch_time 4.01min
# D:\squeezenet\Tesloyta\utils\trainer.py:47: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   self.args.grad_norm)
# | data 9487.5ms | net 558.4ms
# | data 0.0ms | net 551.4ms
# | data 0.0ms | net 549.4ms
# | data 0.0ms | net 549.5ms
# | data 0.0ms | net 551.0ms
# | data 0.0ms | net 548.5ms
# | data 0.0ms | net 565.0ms
# | data 0.0ms | net 546.6ms
# | data 0.0ms | net 545.8ms
# | data 0.0ms | net 553.6ms
# | data 1.0ms | net 552.0ms
# | data 0.0ms | net 551.2ms
# | data 0.0ms | net 551.7ms
# | data 0.0ms | net 563.9ms
# | data 0.0ms | net 547.7ms
# | data 0.0ms | net 567.1ms
# | data 0.0ms | net 553.3ms
# | data 0.0ms | net 550.4ms
# | data 0.0ms | net 555.4ms
# | data 0.0ms | net 548.2ms
# | data 0.0ms | net 564.9ms
# | data 0.0ms | net 565.0ms
# | data 0.0ms | net 550.4ms
# | data 0.0ms | net 549.4ms
# | data 0.0ms | net 548.2ms
# | data 0.0ms | net 551.0ms
# | data 0.0ms | net 551.1ms
# | data 0.0ms | net 551.2ms
# | data 0.0ms | net 552.4ms
# | data 0.0ms | net 554.8ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 551.1ms
# epoch 5:  train | loss 2.884 | class_loss 0.691 | score_loss 0.764 | bbox_loss 1.429 | epoch_time 3.04min
#
# | data 6356.3ms | net 241.6ms
# | data 0.0ms | net 179.0ms
# | data 516.6ms | net 191.1ms
# | data 0.0ms | net 187.5ms
# | data 486.1ms | net 187.5ms
# | data 0.0ms | net 187.4ms
# | data 951.0ms | net 193.4ms
# | data 0.0ms | net 172.9ms
# | data 1081.9ms | net 187.4ms
# | data 0.0ms | net 187.4ms
# | data 518.8ms | net 182.0ms
# | data 1.0ms | net 178.2ms
# | data 689.8ms | net 187.5ms
# | data 0.0ms | net 190.1ms
# | data 927.1ms | net 172.3ms
# | data 0.0ms | net 187.5ms
# epoch 5:  val   | loss 2.823 | class_loss 0.680 | score_loss 0.732 | bbox_loss 1.410 | epoch_time 1.09min
#
# loaded model D:\squeezenet\exp\default\model_5.pth, epoc 5
# Model successfully loaded.
# eval: [(0)/156] | data 5.753s | net0.377s
# eval: [(0)/156] | data 0.000s | net0.268s
# eval: [(0)/156] | data 0.000s | net0.236s
# eval: [(0)/156] | data 0.000s | net0.237s
# eval: [(0)/156] | data 0.000s | net0.234s
# eval: [(0)/156] | data 0.001s | net0.233s
# eval: [(0)/156] | data 0.000s | net0.253s
# eval: [(0)/156] | data 0.000s | net0.250s
# eval: [(0)/156] | data 0.016s | net0.237s
# eval: [(0)/156] | data 0.016s | net0.247s
# eval: [(0)/156] | data 0.000s | net0.234s
# eval: [(0)/156] | data 0.000s | net0.239s
# eval: [(0)/156] | data 0.000s | net0.250s
# eval: [(0)/156] | data 0.000s | net0.221s
# eval: [(0)/156] | data 0.000s | net0.266s
# eval: [(0)/156] | data 0.000s | net0.203s
# Elapsed 0.73min (17.6ms/image, 56.7frames/s)
# --------------------------------------------------------------------------------
# epoch 5:  val   | Car_easy 0.000 | Car_moderate 0.000 | Car_hard 0.000 | Pedestrian_easy 0.000 | Pedestrian_moderate 0.000 | Pedestrian_hard 0.000 | Cyclist_easy 0.000 | Cyclist_moderate 0.000 | Cyclist_hard 0.000 | Van_easy 0.000 | Van_moderate 0.000 | Van_hard 0.000 | Truck_easy 0.000 | Truck_moderate 0.000 | Truck_hard 0.000 | mAP 0.000
#
# Best loss: 2.823 (epoch 5)
# Best class_loss: 0.680 (epoch 5)
# Best score_loss: 0.732 (epoch 5)
# Best bbox_loss: 1.410 (epoch 5)
# Best mAP: 0.000 (epoch 5)
# D:\squeezenet\Tesloyta\utils\trainer.py:47: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   self.args.grad_norm)
# | data 5594.1ms | net 717.4ms
# | data 15.6ms | net 548.2ms
# | data 0.0ms | net 567.3ms
# | data 0.0ms | net 549.5ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 549.4ms
# | data 1.0ms | net 551.9ms
# | data 0.0ms | net 549.4ms
# | data 0.0ms | net 541.7ms
# | data 0.0ms | net 563.7ms
# | data 0.0ms | net 565.1ms
# | data 0.0ms | net 546.8ms
# | data 0.0ms | net 552.5ms
# | data 0.0ms | net 548.5ms
# | data 1.0ms | net 542.4ms
# | data 1.0ms | net 546.9ms
# | data 0.0ms | net 565.1ms
# | data 0.0ms | net 553.3ms
# | data 0.0ms | net 566.0ms
# | data 0.0ms | net 559.5ms
# | data 0.0ms | net 549.8ms
# | data 0.0ms | net 550.1ms
# | data 0.0ms | net 549.4ms
# | data 0.0ms | net 548.4ms
# | data 0.0ms | net 548.9ms
# | data 0.0ms | net 551.4ms
# | data 0.0ms | net 547.5ms
# | data 0.0ms | net 545.4ms
# | data 0.0ms | net 563.3ms
# | data 0.0ms | net 563.0ms
# | data 0.0ms | net 565.1ms
# | data 0.0ms | net 548.7ms
# epoch 6:  train | loss 2.887 | class_loss 0.691 | score_loss 0.760 | bbox_loss 1.436 | epoch_time 2.97min
#
# Best loss: 2.823 (epoch 5)
# Best class_loss: 0.680 (epoch 5)
# Best score_loss: 0.732 (epoch 5)
# Best bbox_loss: 1.410 (epoch 5)
# Best mAP: 0.000 (epoch 5)
# D:\squeezenet\Tesloyta\utils\trainer.py:47: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   self.args.grad_norm)
# | data 5730.3ms | net 571.6ms
# | data 0.0ms | net 549.4ms
# | data 0.0ms | net 547.5ms
# | data 0.0ms | net 549.7ms
# | data 0.0ms | net 551.7ms
# | data 0.0ms | net 564.8ms
# | data 0.0ms | net 564.3ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 553.3ms
# | data 1.0ms | net 542.4ms
# | data 0.0ms | net 549.3ms
# | data 1.0ms | net 545.1ms
# | data 0.0ms | net 565.0ms
# | data 0.0ms | net 562.3ms
# | data 0.0ms | net 549.7ms
# | data 0.0ms | net 549.5ms
# | data 0.0ms | net 564.3ms
# | data 0.0ms | net 552.4ms
# | data 0.0ms | net 549.5ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 563.2ms
# | data 0.0ms | net 551.8ms
# | data 0.0ms | net 564.6ms
# | data 0.0ms | net 552.3ms
# | data 0.0ms | net 549.7ms
# | data 0.0ms | net 547.7ms
# | data 0.0ms | net 551.0ms
# | data 0.0ms | net 565.1ms
# | data 1.0ms | net 552.0ms
# | data 0.0ms | net 561.4ms
# | data 0.0ms | net 564.9ms
# | data 0.0ms | net 549.0ms
# epoch 7:  train | loss 2.888 | class_loss 0.695 | score_loss 0.761 | bbox_loss 1.432 | epoch_time 2.98min
#
# Best loss: 2.823 (epoch 5)
# Best class_loss: 0.680 (epoch 5)
# Best score_loss: 0.732 (epoch 5)
# Best bbox_loss: 1.410 (epoch 5)
# Best mAP: 0.000 (epoch 5)
# D:\squeezenet\Tesloyta\utils\trainer.py:47: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   self.args.grad_norm)
# | data 6001.5ms | net 560.8ms
# | data 0.0ms | net 546.3ms
# | data 0.0ms | net 549.7ms
# | data 0.0ms | net 549.4ms
# | data 0.0ms | net 565.2ms
# | data 0.0ms | net 549.5ms
# | data 0.0ms | net 558.0ms
# | data 0.0ms | net 556.9ms
# | data 0.0ms | net 557.9ms
# | data 0.0ms | net 550.3ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 550.5ms
# | data 15.8ms | net 554.0ms
# | data 0.0ms | net 553.5ms
# | data 1.0ms | net 557.8ms
# | data 0.0ms | net 560.0ms
# | data 0.0ms | net 596.4ms
# | data 0.0ms | net 595.3ms
# | data 0.0ms | net 596.4ms
# | data 0.0ms | net 597.2ms
# | data 0.0ms | net 599.5ms
# | data 0.0ms | net 609.9ms
# | data 0.0ms | net 596.2ms
ms
# | data 0.0ms | net 187.5ms
# | data 0.0ms | net 203.1ms
# epoch 10: val   | loss 2.777 | class_loss 0.670 | score_loss 0.732 | bbox_loss 1.375 | epoch_time 0.67min
#
# loaded model D:\squeezenet\exp\default\model_10.pth, epoc 10
# Model successfully loaded.
# eval: [(0)/156] | data 5.841s | net0.220s
# eval: [(0)/156] | data 0.000s | net0.235s
# eval: [(0)/156] | data 0.000s | net0.234s
# eval: [(0)/156] | data 0.000s | net0.251s
# eval: [(0)/156] | data 0.001s | net0.223s
# eval: [(0)/156] | data 0.000s | net0.219s
# eval: [(0)/156] | data 0.000s | net0.269s
# eval: [(0)/156] | data 0.000s | net0.246s
# eval: [(0)/156] | data 0.001s | net0.220s
# eval: [(0)/156] | data 0.000s | net0.250s
# eval: [(0)/156] | data 0.000s | net0.248s
# eval: [(0)/156] | data 0.000s | net0.235s
# eval: [(0)/156] | data 0.000s | net0.250s
# eval: [(0)/156] | data 0.000s | net0.245s
# eval: [(0)/156] | data 0.001s | net0.220s
# eval: [(0)/156] | data 0.000s | net0.203s
# Elapsed 0.72min (17.3ms/image, 57.9frames/s)
# --------------------------------------------------------------------------------
# epoch 10: val   | Car_easy 0.000 | Car_moderate 0.000 | Car_hard 0.000 | Pedestrian_easy 0.000 | Pedestrian_moderate 0.000 | Pedestrian_hard 0.000 | Cyclist_easy 0.000 | Cyclist_moderate 0.000 | Cyclist_hard 0.000 | Van_easy 0.000 | Van_moderate 0.000 | Van_hard 0.000 | Truck_easy 0.000 | Truck_moderate 0.000 | Truck_hard 0.000 | mAP 0.000
#
# Best loss: 2.777 (epoch 10)
# Best class_loss: 0.670 (epoch 10)
# Best score_loss: 0.732 (epoch 10)
# Best bbox_loss: 1.375 (epoch 10)
# Best mAP: 0.000 (epoch 5)
# D:\squeezenet\Tesloyta\utils\trainer.py:47: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   self.args.grad_norm)
# | data 5690.2ms | net 738.5ms
# | data 0.0ms | net 548.6ms
# | data 0.0ms | net 552.4ms
# | data 0.0ms | net 547.5ms
# | data 0.0ms | net 550.1ms
# | data 15.6ms | net 549.4ms
# | data 0.0ms | net 561.0ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 548.9ms
# | data 0.0ms | net 563.1ms
# | data 0.0ms | net 551.5ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 558.2ms
# | data 0.0ms | net 548.3ms
# | data 0.0ms | net 549.6ms
# | data 15.6ms | net 548.8ms
# | data 0.0ms | net 551.4ms
# | data 0.0ms | net 548.4ms
# | data 0.0ms | net 561.6ms
# | data 0.0ms | net 548.6ms
# | data 0.0ms | net 548.6ms
# | data 0.0ms | net 553.1ms
# | data 0.0ms | net 564.9ms
# | data 0.0ms | net 565.3ms
# | data 0.0ms | net 565.1ms
# | data 0.0ms | net 738.1ms
# | data 0.0ms | net 564.4ms
# | data 0.0ms | net 549.2ms
# | data 15.7ms | net 551.0ms
# | data 0.0ms | net 548.6ms
# | data 0.0ms | net 565.4ms
# | data 0.0ms | net 548.7ms
# epoch 11: train | loss 2.856 | class_loss 0.694 | score_loss 0.763 | bbox_loss 1.399 | epoch_time 3.01min
#
# Best loss: 2.777 (epoch 10)
# Best class_loss: 0.670 (epoch 10)
# Best score_loss: 0.732 (epoch 10)
# Best bbox_loss: 1.375 (epoch 10)
# Best mAP: 0.000 (epoch 5)
# D:\squeezenet\Tesloyta\utils\trainer.py:47: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   self.args.grad_norm)
# | data 6075.4ms | net 564.0ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 548.5ms
# | data 0.0ms | net 555.7ms
# | data 0.0ms | net 548.6ms
# | data 0.0ms | net 549.5ms
# | data 0.0ms | net 563.2ms
# | data 0.0ms | net 563.2ms
# | data 15.6ms | net 551.2ms
# | data 0.0ms | net 552.4ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 548.5ms
# | data 0.0ms | net 563.1ms
# | data 0.0ms | net 548.4ms
# | data 0.0ms | net 549.5ms
# | data 0.0ms | net 547.4ms
# | data 0.0ms | net 720.4ms
# | data 0.0ms | net 581.1ms
# | data 15.6ms | net 551.6ms
# | data 0.0ms | net 570.5ms
# | data 0.0ms | net 549.4ms
# | data 0.0ms | net 555.4ms
# | data 0.0ms | net 562.9ms
# | data 0.0ms | net 563.8ms
# | data 0.0ms | net 536.7ms
# | data 0.0ms | net 545.9ms
# | data 0.0ms | net 546.4ms
# | data 1.0ms | net 576.3ms
# | data 0.0ms | net 571.8ms
# | data 0.0ms | net 578.2ms
# | data 1.0ms | net 581.9ms
# | data 0.0ms | net 556.1ms
# epoch 12: train | loss 2.847 | class_loss 0.686 | score_loss 0.761 | bbox_loss 1.400 | epoch_time 3.03min
#
# Best loss: 2.777 (epoch 10)
# Best class_loss: 0.670 (epoch 10)
# Best score_loss: 0.732 (epoch 10)
# Best bbox_loss: 1
# epoch 15: train | loss 2.847 | class_loss 0.690 | score_loss 0.761 | bbox_loss 1.397 | epoch_time 3.09min
#
# | data 5479.4ms | net 218.7ms
# | data 0.0ms | net 191.4ms
# | data 155.8ms | net 190.5ms
# | data 0.0ms | net 187.5ms
# | data 109.4ms | net 187.5ms
# | data 0.0ms | net 187.5ms
# | data 156.2ms | net 190.0ms
# | data 0.0ms | net 173.6ms
# | data 148.0ms | net 187.5ms
# | data 0.0ms | net 187.5ms
# | data 109.4ms | net 185.3ms
# | data 0.0ms | net 189.2ms
# | data 108.1ms | net 206.9ms
# | data 0.0ms | net 181.2ms
# | data 140.6ms | net 203.1ms
# | data 0.0ms | net 187.5ms
# epoch 15: val   | loss 2.761 | class_loss 0.669 | score_loss 0.797 | bbox_loss 1.295 | epoch_time 0.67min
#
# loaded model D:\squeezenet\exp\default\model_15.pth, epoc 15
# Model successfully loaded.
# eval: [(0)/156] | data 6.030s | net0.239s
# eval: [(0)/156] | data 0.000s | net0.226s
# eval: [(0)/156] | data 0.000s | net0.252s
# eval: [(0)/156] | data 0.000s | net0.234s
# eval: [(0)/156] | data 0.000s | net0.248s
# eval: [(0)/156] | data 0.000s | net0.250s
# eval: [(0)/156] | data 0.000s | net0.237s
# eval: [(0)/156] | data 0.000s | net0.250s
# eval: [(0)/156] | data 0.000s | net0.241s
# eval: [(0)/156] | data 0.000s | net0.252s
# eval: [(0)/156] | data 0.001s | net0.232s
# eval: [(0)/156] | data 0.016s | net0.234s
# eval: [(0)/156] | data 0.001s | net0.234s
# eval: [(0)/156] | data 0.000s | net0.234s
# eval: [(0)/156] | data 0.000s | net0.235s
# eval: [(0)/156] | data 0.016s | net0.219s
# Elapsed 0.72min (17.4ms/image, 57.5frames/s)
# --------------------------------------------------------------------------------
# epoch 15: val   | Car_easy 0.000 | Car_moderate 0.000 | Car_hard 0.000 | Pedestrian_easy 0.000 | Pedestrian_moderate 0.000 | Pedestrian_hard 0.000 | Cyclist_easy 0.000 | Cyclist_moderate 0.000 | Cyclist_hard 0.000 | Van_easy 0.000 | Van_moderate 0.000 | Van_hard 0.000 | Truck_easy 0.000 | Truck_moderate 0.000 | Truck_hard 0.000 | mAP 0.000
#
# Best loss: 2.761 (epoch 15)
# Best class_loss: 0.669 (epoch 15)
# Best score_loss: 0.732 (epoch 10)
# Best bbox_loss: 1.295 (epoch 15)
# Best mAP: 0.000 (epoch 5)
# D:\squeezenet\Tesloyta\utils\trainer.py:47: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   self.args.grad_norm)
# | data 5843.3ms | net 709.4ms
# | data 0.0ms | net 545.5ms
# | data 0.0ms | net 552.9ms
# | data 0.0ms | net 565.1ms
# | data 0.0ms | net 562.8ms
# | data 0.0ms | net 549.4ms
# | data 0.0ms | net 551.7ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 552.1ms
# | data 0.0ms | net 642.2ms
# | data 0.0ms | net 627.7ms
# | data 0.0ms | net 563.8ms
# | data 0.0ms | net 565.1ms
# | data 0.0ms | net 565.0ms
# | data 0.0ms | net 564.3ms
# | data 0.0ms | net 565.1ms
# | data 0.0ms | net 555.9ms
# | data 0.0ms | net 566.2ms
# | data 0.0ms | net 565.1ms
# | data 0.0ms | net 548.8ms
# | data 0.0ms | net 549.5ms
# | data 0.0ms | net 564.1ms
# | data 0.0ms | net 562.3ms
# | data 0.0ms | net 611.9ms
# | data 0.0ms | net 619.1ms
# | data 1.0ms | net 638.1ms
# | data 0.0ms | net 608.1ms
# | data 0.0ms | net 614.0ms
# | data 0.0ms | net 628.0ms
# | data 0.0ms | net 598.9ms
# | data 0.0ms | net 564.3ms
# | data 0.0ms | net 565.1ms
# epoch 16: train | loss 2.843 | class_loss 0.689 | score_loss 0.759 | bbox_loss 1.394 | epoch_time 3.09min
#
# Best loss: 2.761 (epoch 15)
# Best class_loss: 0.669 (epoch 15)
# Best score_loss: 0.732 (epoch 10)
# Best bbox_loss: 1

# Best class_loss: 0.669 (epoch 15)
# Best score_loss: 0.732 (epoch 10)
# Best bbox_loss: 1.295 (epoch 15)
# Best mAP: 0.000 (epoch 5)
# D:\squeezenet\Tesloyta\utils\trainer.py:47: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   self.args.grad_norm)
# | data 5952.5ms | net 567.8ms
# | data 0.0ms | net 564.2ms
# | data 0.0ms | net 550.8ms
# | data 0.0ms | net 548.5ms
# | data 0.0ms | net 562.2ms
# | data 0.0ms | net 550.3ms
# | data 0.0ms | net 556.1ms
# | data 0.0ms | net 551.6ms
# | data 0.0ms | net 549.3ms
# | data 0.0ms | net 565.9ms
# | data 0.0ms | net 549.4ms
# | data 0.0ms | net 583.7ms
# | data 0.0ms | net 596.4ms
# | data 0.0ms | net 591.3ms
# | data 0.0ms | net 578.9ms
# | data 0.0ms | net 579.7ms
# | data 0.0ms | net 596.2ms
# | data 0.0ms | net 583.8ms
# | data 0.0ms | net 568.4ms
# | data 0.0ms | net 579.5ms
# | data 0.0ms | net 579.7ms
# | data 0.0ms | net 580.8ms
# | data 0.0ms | net 580.8ms
# | data 0.0ms | net 546.0ms
# | data 0.0ms | net 565.1ms
# | data 0.0ms | net 544.9ms
# | data 0.0ms | net 597.0ms
# | data 0.0ms | net 597.0ms
# | data 0.0ms | net 592.6ms
# | data 0.0ms | net 597.3ms
# | data 0.0ms | net 595.2ms
# | data 0.0ms | net 550.5ms
# epoch 20: train | loss 2.826 | class_loss 0.686 | score_loss 0.759 | bbox_loss 1.381 | epoch_time 3.08min
#
# | data 5583.0ms | net 237.0ms
# | data 0.0ms | net 205.7ms
# | data 0.0ms | net 190.0ms
# | data 0.0ms | net 187.5ms
# | data 78.1ms | net 187.5ms
# | data 0.0ms | net 187.5ms
# | data 109.3ms | net 187.5ms
# | data 0.0ms | net 187.5ms
# | data 125.0ms | net 202.3ms
# | data 0.0ms | net 195.7ms
# | data 0.0ms | net 206.7ms
# | data 112.7ms | net 187.5ms
# | data 0.0ms | net 196.2ms
# | data 109.4ms | net 218.0ms
# | data 0.0ms | net 190.1ms
# | data 76.9ms | net 191.3ms
# epoch 20: val   | loss 2.750 | class_loss 0.671 | score_loss 0.781 | bbox_loss 1.299 | epoch_time 0.66min
#
# loaded model D:\squeezenet\exp\default\model_20.pth, epoc 20
# Model successfully loaded.
# eval: [(0)/156] | data 5.828s | net0.248s
# eval: [(0)/156] | data 0.000s | net0.235s
# eval: [(0)/156] | data 0.000s | net0.258s
# eval: [(0)/156] | data 0.000s | net0.234s
# eval: [(0)/156] | data 0.000s | net0.236s
# eval: [(0)/156] | data 0.000s | net0.250s
# eval: [(0)/156] | data 0.000s | net0.237s
# eval: [(0)/156] | data 0.000s | net0.250s
# eval: [(0)/156] | data 0.000s | net0.248s
# eval: [(0)/156] | data 0.000s | net0.234s
# eval: [(0)/156] | data 0.000s | net0.222s
# eval: [(0)/156] | data 0.000s | net0.265s
# eval: [(0)/156] | data 0.001s | net0.231s
# eval: [(0)/156] | data 0.000s | net0.253s
# eval: [(0)/156] | data 0.000s | net0.250s
# eval: [(0)/156] | data 0.000s | net0.215s
# Elapsed 0.73min (17.5ms/image, 57.2frames/s)
# --------------------------------------------------------------------------------
# epoch 20: val   | Car_easy 0.000 | Car_moderate 0.000 | Car_hard 0.000 | Pedestrian_easy 0.000 | Pedestrian_moderate 0.000 | Pedestrian_hard 0.000 | Cyclist_easy 0.000 | Cyclist_moderate 0.000 | Cyclist_hard 0.000 | Van_easy 0.000 | Van_moderate 0.000 | Van_hard 0.000 | Truck_easy 0.000 | Truck_moderate 0.000 | Truck_hard 0.000 | mAP 0.000
#
# Best loss: 2.750 (epoch 20)
# Best class_loss: 0.669 (epoch 15)
# Best score_loss: 0.732 (epoch 10)
# Best bbox_loss: 1

# Best class_loss: 0.669 (epoch 15)
# Best score_loss: 0.732 (epoch 10)
# Best bbox_loss: 1.295 (epoch 15)
# Best mAP: 0.000 (epoch 5)
# D:\squeezenet\Tesloyta\utils\trainer.py:47: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   self.args.grad_norm)
# | data 5366.9ms | net 563.6ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 565.0ms
# | data 0.0ms | net 563.4ms
# | data 0.0ms | net 564.4ms
# | data 0.0ms | net 551.5ms
# | data 0.0ms | net 548.8ms
# | data 0.0ms | net 554.6ms
# | data 0.0ms | net 554.5ms
# | data 0.0ms | net 550.5ms
# | data 1.0ms | net 535.9ms
# | data 0.0ms | net 553.8ms
# | data 0.0ms | net 551.7ms
# | data 0.0ms | net 552.5ms
# | data 0.0ms | net 549.9ms
# | data 0.0ms | net 547.7ms
# | data 0.0ms | net 548.6ms
# | data 0.0ms | net 564.3ms
# | data 0.0ms | net 557.3ms
# | data 0.0ms | net 545.7ms
# | data 0.0ms | net 564.5ms
# | data 0.0ms | net 552.4ms
# | data 0.0ms | net 565.0ms
# | data 0.0ms | net 566.2ms
# | data 0.0ms | net 548.3ms
# | data 0.0ms | net 549.4ms
# | data 0.0ms | net 565.2ms
# | data 0.0ms | net 568.2ms
# | data 0.0ms | net 551.1ms
# | data 0.0ms | net 564.1ms
# | data 0.0ms | net 552.5ms
# | data 1.0ms | net 536.3ms
# epoch 24: train | loss 2.815 | class_loss 0.688 | score_loss 0.761 | bbox_loss 1.366 | epoch_time 2.97min
#
# Best loss: 2.750 (epoch 20)
# Best class_loss: 0.669 (epoch 15)
# Best score_loss: 0.732 (epoch 10)
# Best bbox_loss: 1.295 (epoch 15)
# Best mAP: 0.000 (epoch 5)
# D:\squeezenet\Tesloyta\utils\trainer.py:47: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   self.args.grad_norm)
# | data 5353.3ms | net 571.8ms
# | data 0.0ms | net 549.5ms
# | data 0.0ms | net 551.1ms
# | data 0.0ms | net 565.2ms
# | data 0.0ms | net 560.5ms
# | data 0.0ms | net 565.3ms
# | data 0.0ms | net 560.9ms
# | data 0.0ms | net 550.7ms
# | data 0.0ms | net 548.6ms
# | data 0.0ms | net 565.2ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 546.9ms
# | data 0.0ms | net 549.7ms
# | data 1.0ms | net 550.1ms
# | data 0.0ms | net 547.6ms
# | data 0.0ms | net 555.6ms
# | data 0.0ms | net 550.4ms
# | data 1.0ms | net 544.1ms
# | data 0.0ms | net 563.8ms
# | data 0.0ms | net 551.7ms
# | data 0.0ms | net 565.8ms
# | data 0.0ms | net 555.5ms
# | data 0.0ms | net 550.4ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 562.6ms
# | data 0.0ms | net 562.9ms
# | data 0.0ms | net 547.6ms
# | data 0.0ms | net 566.3ms
# | data 0.0ms | net 549.7ms
# | data 0.0ms | net 547.1ms
# | data 0.0ms | net 562.9ms
# | data 0.0ms | net 551.3ms
# epoch 25: train | loss 2.811 | class_loss 0.691 | score_loss 0.756 | bbox_loss 1.364 | epoch_time 2.97min
#
# | data 5170.1ms | net 222.6ms
# | data 0.0ms | net 186.2ms
# | data 0.0ms | net 187.5ms
# | data 0.0ms | net 193.1ms
# | data 0.0ms | net 187.5ms
# | data 0.0ms | net 190.1ms
# | data 0.0ms | net 187.5ms
# | data 0.0ms | net 196.1ms
# | data 0.0ms | net 200.4ms
# | data 0.0ms | net 203.1ms
# | data 0.0ms | net 207.7ms
# | data 0.0ms | net 187.5ms
# | data 0.0ms | net 187.5ms
# | data 0.0ms | net 185.2ms
# | data 0.0ms | net 190.0ms
# | data 0.0ms | net 187.5ms
# epoch 25: val   | loss 2.744 | class_loss 0.673 | score_loss 0.793 | bbox_loss 1.278 | epoch_time 0.59min
#
# loaded model D:\squeezenet\exp\default\model_25.pth, epoc 25
# Model successfully loaded.
# eval: [(0)/156] | data 5.257s | net0.237s
# eval: [(0)/156] | data 0.000s | net0.219s
# eval: [(0)/156] | data 0.000s | net0.219s
# eval: [(0)/156] | data 0.000s | net0.227s
# eval: [(0)/156] | data 0.000s | net0.220s
# eval: [(0)/156] | data 0.000s | net0.234s
# eval: [(0)/156] | data 0.000s | net0.219s
# eval: [(0)/156] | data 0.000s | net0.236s
# eval: [(0)/156] | data 0.000s | net0.224s
# eval: [(0)/156] | data 0.000s | net0.219s
# eval: [(0)/156] | data 0.000s | net0.219s
# eval: [(0)/156] | data 0.000s | net0.217s
# eval: [(0)/156] | data 0.000s | net0.237s
# eval: [(0)/156] | data 0.000s | net0.223s
# eval: [(0)/156] | data 0.000s | net0.219s
# eval: [(0)/156] | data 0.000s | net0.203s
# Elapsed 0.67min (16.2ms/image, 61.8frames/s)
# --------------------------------------------------------------------------------
# epoch 25: val   | Car_easy 0.000 | Car_moderate 0.000 | Car_hard 0.000 | Pedestrian_easy 0.000 | Pedestrian_moderate 0.000 | Pedestrian_hard 0.000 | Cyclist_easy 0.000 | Cyclist_moderate 0.000 | Cyclist_hard 0.000 | Van_easy 0.000 | Van_moderate 0.000 | Van_hard 0.000 | Truck_easy 0.000 | Truck_moderate 0.000 | Truck_hard 0.000 | mAP 0.000
#
# Best loss: 2.744 (epoch 25)
# Best class_loss: 0.669 (epoch 15)
# Best score_loss: 0.732 (epoch 10)
# Best bbox_loss: 1
ms
# | data 0.0ms | net 548.7ms
# | data 0.0ms | net 556.2ms
# | data 0.0ms | net 551.6ms
# | data 0.0ms | net 559.1ms
# | data 0.0ms | net 548.4ms
# | data 0.0ms | net 549.4ms
# | data 0.0ms | net 563.2ms
# | data 0.0ms | net 549.5ms
# | data 0.0ms | net 547.4ms
# | data 0.0ms | net 548.7ms
# epoch 145: train | loss 2.778 | class_loss 0.677 | score_loss 0.756 | bbox_loss 1.345 | epoch_time 2.97min
#
# | data 5082.2ms | net 237.0ms
# | data 0.0ms | net 187.5ms
# | data 0.0ms | net 187.5ms
# | data 0.0ms | net 185.3ms
# | data 15.6ms | net 171.8ms
# | data 0.0ms | net 189.1ms
# | data 0.0ms | net 187.5ms
# | data 0.0ms | net 189.8ms
# | data 0.0ms | net 187.5ms
# | data 0.0ms | net 183.2ms
# | data 0.0ms | net 185.2ms
# | data 0.0ms | net 187.5ms
# | data 0.0ms | net 190.0ms
# | data 0.0ms | net 189.2ms
# | data 0.0ms | net 187.5ms
# | data 0.0ms | net 187.5ms
# epoch 145: val   | loss 2.706 | class_loss 0.658 | score_loss 0.767 | bbox_loss 1.281 | epoch_time 0.59min
#
# loaded model D:\squeezenet\exp\default\model_145.pth, epoc 145
# Model successfully loaded.
# eval: [(0)/156] | data 5.318s | net0.237s
# eval: [(0)/156] | data 0.000s | net0.210s
# eval: [(0)/156] | data 0.000s | net0.219s
# eval: [(0)/156] | data 0.000s | net0.219s
# eval: [(0)/156] | data 0.000s | net0.221s
# eval: [(0)/156] | data 0.000s | net0.222s
# eval: [(0)/156] | data 0.000s | net0.219s
# eval: [(0)/156] | data 0.000s | net0.219s
# eval: [(0)/156] | data 0.000s | net0.234s
# eval: [(0)/156] | data 0.000s | net0.222s
# eval: [(0)/156] | data 0.000s | net0.235s
# eval: [(0)/156] | data 0.000s | net0.234s
# eval: [(0)/156] | data 0.000s | net0.219s
# eval: [(0)/156] | data 0.000s | net0.232s
# eval: [(0)/156] | data 0.000s | net0.206s
# eval: [(0)/156] | data 0.000s | net0.209s
# Elapsed 0.67min (16.2ms/image, 61.9frames/s)
# --------------------------------------------------------------------------------
# epoch 145: val   | Car_easy 0.000 | Car_moderate 0.000 | Car_hard 0.000 | Pedestrian_easy 0.000 | Pedestrian_moderate 0.000 | Pedestrian_hard 0.000 | Cyclist_easy 0.000 | Cyclist_moderate 0.000 | Cyclist_hard 0.000 | Van_easy 0.000 | Van_moderate 0.000 | Van_hard 0.000 | Truck_easy 0.000 | Truck_moderate 0.000 | Truck_hard 0.000 | mAP 0.000
#
# Best loss: 2.704 (epoch 115)
# Best class_loss: 0.658 (epoch 145)
# Best score_loss: 0.732 (epoch 10)
# Best bbox_loss: 1.266 (epoch 35)
# Best mAP: 0.000 (epoch 5)
# D:\squeezenet\Tesloyta\utils\trainer.py:47: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   self.args.grad_norm)
# | data 5302.6ms | net 689.9ms
# | data 0.0ms | net 563.2ms
# | data 0.0ms | net 543.1ms
# | data 0.0ms | net 547.5ms
# | data 15.6ms | net 550.6ms
# | data 0.0ms | net 549.7ms
# | data 0.0ms | net 550.2ms
# | data 0.0ms | net 535.1ms
# | data 0.0ms | net 548.5ms
# | data 0.0ms | net 549.1ms
# | data 0.0ms | net 549.7ms
# | data 0.0ms | net 555.2ms
# | data 0.0ms | net 549.5ms
# | data 0.0ms | net 548.6ms
# | data 0.0ms | net 549.8ms
# | data 0.0ms | net 549.8ms
# | data 0.0ms | net 564.3ms
# | data 0.0ms | net 564.3ms
# | data 15.6ms | net 549.7ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 549.8ms
# | data 0.0ms | net 549.7ms
# | data 0.0ms | net 566.2ms
# | data 0.0ms | net 560.9ms
# | data 0.0ms | net 565.5ms
# | data 0.0ms | net 549.5ms
# | data 0.0ms | net 548.7ms
# | data 0.0ms | net 548.2ms
# | data 1.0ms | net 547.1ms
# | data 0.0ms | net 549.8ms
# | data 0.0ms | net 577.6ms
# | data 0.0ms | net 553.5ms
# epoch 146: train | loss 2.777 | class_loss 0.674 | score_loss 0.756 | bbox_loss 1.347 | epoch_time 2.97min
#
# Best loss: 2.704 (epoch 115)
# Best class_loss: 0.658 (epoch 145)
# Best score_loss: 0.732 (epoch 10)
# Best bbox_loss: 1.266 (epoch 35)
# Best mAP: 0.000 (epoch 5)
# D:\squeezenet\Tesloyta\utils\trainer.py:47: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   self.args.grad_norm)
# | data 5430.3ms | net 562.9ms
# | data 0.0ms | net 549.5ms
# | data 0.0ms | net 563.0ms
# | data 0.0ms | net 563.0ms
# | data 0.0ms | net 563.0ms
# | data 0.0ms | net 548.4ms
# | data 0.0ms | net 534.2ms
# | data 0.0ms | net 549.7ms
# | data 0.0ms | net 562.9ms
# | data 0.0ms | net 551.5ms
# | data 0.0ms | net 548.7ms
# | data 0.0ms | net 565.2ms
# | data 0.0ms | net 538.3ms
# | data 0.0ms | net 549.8ms
# | data 0.0ms | net 579.7ms
# | data 15.6ms | net 556.8ms
# | data 15.6ms | net 549.8ms
# | data 15.6ms | net 536.8ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 549.9ms
# | data 0.0ms | net 564.1ms
# | data 0.0ms | net 565.3ms
# | data 0.0ms | net 549.4ms
# | data 1.0ms | net 548.9ms
# | data 0.0ms | net 563.2ms
# | data 15.7ms | net 534.3ms
# | data 0.0ms | net 543.5ms
# | data 1.0ms | net 539.2ms
# | data 0.0ms | net 566.1ms
# | data 0.0ms | net 552.5ms
# | data 0.0ms | net 565.1ms
# | data 0.0ms | net 549.7ms
# epoch 147: train | loss 2.768 | class_loss 0.672 | score_loss 0.755 | bbox_loss 1.340 | epoch_time 2.97min
#
# Best loss: 2.704 (epoch 115)
# Best class_loss: 0.658 (epoch 145)
# Best score_loss: 0.732 (epoch 10)
# Best bbox_loss: 1.266 (epoch 35)
# Best mAP: 0.000 (epoch 5)
# D:\squeezenet\Tesloyta\utils\trainer.py:47: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   self.args.grad_norm)
# | data 5513.6ms | net 558.3ms
# | data 0.0ms | net 550.5ms
# | data 0.0ms | net 550.5ms
# | data 0.0ms | net 549.7ms
# | data 0.0ms | net 549.4ms
# | data 0.0ms | net 549.7ms
# | data 0.0ms | net 565.2ms
# | data 0.0ms | net 549.8ms
# | data 0.0ms | net 552.4ms
# | data 1.0ms | net 538.1ms
# | data 0.0ms | net 548.5ms
# | data 0.0ms | net 576.7ms
# | data 0.0ms | net 547.5ms
# | data 0.0ms | net 553.1ms
# | data 15.6ms | net 547.2ms
# | data 0.0ms | net 550.2ms
# | data 0.0ms | net 551.3ms
# | data 0.0ms | net 565.1ms
# | data 0.0ms | net 549.5ms
# | data 0.0ms | net 539.3ms
# | data 0.0ms | net 549.4ms
# | data 0.0ms | net 547.4ms
# | data 0.0ms | net 563.3ms
# | data 0.0ms | net 550.4ms
# | data 0.0ms | net 567.4ms
# | data 0.0ms | net 548.5ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 551.5ms
# | data 0.0ms | net 550.4ms
# | data 0.0ms | net 549.4ms
# | data 1.0ms | net 555.7ms
# | data 0.0ms | net 551.7ms
# epoch 148: train | loss 2.770 | class_loss 0.676 | score_loss 0.756 | bbox_loss 1.338 | epoch_time 2.97min
#
# Best loss: 2.704 (epoch 115)
# Best class_loss: 0.658 (epoch 145)
# Best score_loss: 0.732 (epoch 10)
# Best bbox_loss: 1.266 (epoch 35)
# Best mAP: 0.000 (epoch 5)
# D:\squeezenet\Tesloyta\utils\trainer.py:47: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   self.args.grad_norm)
# | data 5459.8ms | net 565.2ms
# | data 0.0ms | net 548.3ms
# | data 0.0ms | net 564.5ms
# | data 0.0ms | net 550.3ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 549.7ms
# | data 0.0ms | net 550.6ms
# | data 0.0ms | net 563.3ms
# | data 0.0ms | net 549.5ms
# | data 15.6ms | net 547.6ms
# | data 0.0ms | net 564.1ms
# | data 0.0ms | net 560.3ms
# | data 0.0ms | net 552.5ms
# | data 0.0ms | net 549.9ms
# | data 0.0ms | net 565.1ms
# | data 0.0ms | net 580.2ms
# | data 0.0ms | net 564.3ms
# | data 1.0ms | net 536.2ms
# | data 0.0ms | net 548.6ms
# | data 1.0ms | net 544.2ms
# | data 0.0ms | net 551.8ms
# | data 0.0ms | net 549.5ms
# | data 0.0ms | net 556.4ms
# | data 0.0ms | net 548.7ms
# | data 0.0ms | net 548.2ms
# | data 0.0ms | net 548.7ms
# | data 0.0ms | net 548.8ms
# | data 0.0ms | net 565.2ms
# | data 0.0ms | net 565.1ms
# | data 0.0ms | net 565.2ms
# | data 0.0ms | net 552.3ms
# epoch 149: train | loss 2.776 | class_loss 0.676 | score_loss 0.758 | bbox_loss 1.342 | epoch_time 2.97min
#
# Best loss: 2.704 (epoch 115)
# Best class_loss: 0.658 (epoch 145)
# Best score_loss: 0.732 (epoch 10)
# Best bbox_loss: 1.266 (epoch 35)
# Best mAP: 0.000 (epoch 5)
# D:\squeezenet\Tesloyta\utils\trainer.py:47: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
#   self.args.grad_norm)
# | data 5536.0ms | net 560.4ms
# | data 0.0ms | net 565.2ms
# | data 0.0ms | net 547.7ms
# | data 0.0ms | net 551.6ms
# | data 0.0ms | net 564.4ms
# | data 0.0ms | net 548.4ms
# | data 0.0ms | net 548.5ms
# | data 0.0ms | net 561.4ms
# | data 0.0ms | net 540.2ms
# | data 0.0ms | net 550.5ms
# | data 0.0ms | net 564.8ms
# | data 0.0ms | net 562.7ms
# | data 0.0ms | net 566.9ms
# | data 0.0ms | net 568.1ms
# | data 0.0ms | net 549.1ms
# | data 0.0ms | net 565.3ms
# | data 0.0ms | net 548.7ms
# | data 0.0ms | net 548.5ms
# | data 0.0ms | net 553.1ms
# | data 0.0ms | net 547.7ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 549.6ms
# | data 0.0ms | net 550.6ms
# | data 0.0ms | net 547.6ms
# | data 15.6ms | net 534.6ms
# | data 0.0ms | net 549.5ms
# | data 0.0ms | net 566.2ms
# | data 0.0ms | net 579.1ms
# | data 0.0ms | net 550.5ms
# | data 0.0ms | net 546.6ms
# | data 0.0ms | net 551.0ms
# | data 0.0ms | net 563.7ms
# epoch 150: train | loss 2.771 | class_loss 0.677 | score_loss 0.754 | bbox_loss 1.341 | epoch_time 2.97min
#
# | data 5069.4ms | net 218.7ms
# | data 0.0ms | net 190.1ms
# | data 0.0ms | net 187.5ms
# | data 1.0ms | net 177.7ms
# | data 15.6ms | net 171.8ms
# | data 0.0ms | net 187.5ms
# | data 0.0ms | net 189.0ms
# | data 0.0ms | net 187.5ms
# | data 0.0ms | net 176.8ms
# | data 0.0ms | net 193.6ms
# | data 0.0ms | net 203.1ms
# | data 0.0ms | net 172.4ms
# | data 0.0ms | net 186.7ms
# | data 0.0ms | net 187.4ms
# | data 0.0ms | net 203.1ms
# | data 0.0ms | net 191.8ms
# epoch 150: val   | loss 2.704 | class_loss 0.659 | score_loss 0.753 | bbox_loss 1.293 | epoch_time 0.59min
#
# loaded model D:\squeezenet\exp\default\model_150.pth, epoc 150
# Model successfully loaded.
# eval: [(0)/156] | data 5.305s | net0.234s
# eval: [(0)/156] | data 0.000s | net0.219s
# eval: [(0)/156] | data 0.000s | net0.222s
# eval: [(0)/156] | data 0.000s | net0.219s
# eval: [(0)/156] | data 0.000s | net0.219s
# eval: [(0)/156] | data 0.000s | net0.233s
# eval: [(0)/156] | data 0.000s | net0.235s
# eval: [(0)/156] | data 0.000s | net0.211s
# eval: [(0)/156] | data 0.000s | net0.219s
# eval: [(0)/156] | data 0.000s | net0.234s
# eval: [(0)/156] | data 0.000s | net0.220s
# eval: [(0)/156] | data 0.000s | net0.222s
# eval: [(0)/156] | data 0.000s | net0.219s
# eval: [(0)/156] | data 0.000s | net0.219s
# eval: [(0)/156] | data 0.000s | net0.231s
# eval: [(0)/156] | data 0.000s | net0.222s
# Elapsed 0.67min (16.2ms/image, 61.8frames/s)
# --------------------------------------------------------------------------------
# epoch 150: val   | Car_easy 0.000 | Car_moderate 0.000 | Car_hard 0.000 | Pedestrian_easy 0.000 | Pedestrian_moderate 0.000 | Pedestrian_hard 0.000 | Cyclist_easy 0.000 | Cyclist_moderate 0.000 | Cyclist_hard 0.000 | Van_easy 0.000 | Van_moderate 0.000 | Van_hard 0.000 | Truck_easy 0.000 | Truck_moderate 0.000 | Truck_hard 0.000 | mAP 0.000
#
# Best loss: 2.704 (epoch 115)
# Best class_loss: 0.658 (epoch 145)
# Best score_loss: 0.732 (epoch 10)
# Best bbox_loss: 1.266 (epoch 35)
# Best mAP: 0.000 (epoch 5)

# %%
from eval import eval
# Out:
# Hello Tesla! I am Trainer
# Hello Tesla!

# %%
eval(args)
# Out:
# anchors                        [[   8.    8.   34.   30.]
#  [   8.    8.   75.   45.]
#  [   8.    8.   38.   90.]
#  ...
#  [1240.  376.  194.  178.]
#  [1240.  376.  283.  156.]
#  [1240.  376.  381.  185.]]
# anchors_per_grid               9
# arch                           squeezedet
# batch_size                     16
# bbox_loss_weight               6.0
# chunk_sizes                    [20]
# class_loss_weight              1.0
# class_names                    ('Car', 'Pedestrian', 'Cyclist')
# data_dir                       J://SqueezeDetect/data/
# dataset                        kitti
# debug                          2
# debug_dir                      C://Users/Billi/repos/Computer_Vision/SqueezeDetect\exp\default\debug
# device                         cpu
# drift_prob                     1.0
# dropout_prob                   0.5
# exp_dir                        C://Users/Billi/repos/Computer_Vision/SqueezeDetect\exp
# exp_id                         default
# flip_prob                      0.5
# forbid_resize                  False
# gpus                           -1
# gpus_str                       0
# grad_norm                      5.0
# input                          0
# input_size                     (384, 1248)
# keep_top_k                     64
# load_model
# lr                             0.01
# master_batch_size              20
# mode                           None
# model                          None
# momentum                       0.9
# negative_score_loss_weight     100.0
# nms_thresh                     0.35
# no_eval                        False
# not_cuda_benchmark             False
# num_anchors                    16848
# num_classes                    3
# num_epochs                     150
# num_iters                      -1
# num_workers                    4
# output                         None
# output_dir                     C://Users/Billi/repos/Computer_Vision/SqueezeDetect\video
# positive_score_loss_weight     3.75
# print_interval                 10
# rgb_mean                       [[[93.877 98.801 95.923]]]
# rgb_std                        [[[78.782 80.13  81.2  ]]]
# root_dir
# save_dir                       C://Users/Billi/repos/Computer_Vision/SqueezeDetect\exp\default
# save_intervals                 1
# score_thresh                   0.3
# seed                           42
# val_intervals                  5
# weight_decay                   0.0001
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-998cb7ae9c8e> in <module>
# ----> 1 eval(args)
#
# ~\repos\Computer_Vision\SqueezeDetect\utils\eval.py in eval(args)
#      14     Args().print(args)
#      15
# ---> 16     aps = eval_dataset(dataset, args.load_model, args)
#      17     for k, v in aps.items():
#      18         print('{:<20} {:.3f}'.format(k, v))
#
# ~\repos\Computer_Vision\SqueezeDetect\utils\eval.py in eval_dataset(dataset, model_path, args)
#      23 def eval_dataset(dataset, model_path, args):
#      24     model = SqueezeDet(args)
# ---> 25     model = load_model(model, model_path)
#      26
#      27     detector = Detector(model, args)
#
# ~\repos\Computer_Vision\SqueezeDetect\utils\load_model.py in load_model(model, model_path)
#       9 def load_model(model, model_path):
#      10
# ---> 11     checkpoint = torch.load(model_path, map_location=lambda storage, loc: storage)
#      12 #    checkpoint = torch.load(model_path, map_location='cpu')
#      13     # 'C://Users/Billi/repos/Computer_Vision/SqueezeDet/utils/squeezedet_kitti_epoch110.pth')
#
# ~\Anaconda3\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     380             (sys.version_info[0] == 2 and isinstance(f, unicode)):
#     381         new_fd = True
# --> 382         f = open(f, 'rb')
#     383     elif (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     384         new_fd = True
#
# FileNotFoundError: [Errno 2] No such file or directory: ''

# %%
import torch
import torch.nn as nn
import torch.nn.init as init
from torch.utils.model_zoo import load_url as load_state_dict_from_url

class Fire(nn.Module):

    def __init__(self, inplanes, squeeze_planes,
                 expand1x1_planes, expand3x3_planes):
        super(Fire, self).__init__()
        self.inplanes = inplanes
        self.squeeze = nn.Conv2d(inplanes, squeeze_planes, kernel_size=1)
        self.squeeze_activation = nn.ReLU(inplace=True)
        self.expand1x1 = nn.Conv2d(squeeze_planes, expand1x1_planes, kernel_size=1)
        self.expand1x1_activation = nn.ReLU(inplace=True)
        self.expand3x3 = nn.Conv2d(squeeze_planes, expand3x3_planes, kernel_size=3, padding=1)
        self.expand3x3_activation = nn.ReLU(inplace=True)

    def forward(self, x):
        x = self.squeeze_activation(self.squeeze(x))
        x = torch.cat([
            self.expand1x1_activation(self.expand1x1(x)),
            self.expand3x3_activation(self.expand3x3(x))
        ], dim=1)
        return x


class SqueezenetDet(nn.Module):

    def __init__(self, arch, num_classes, num_anchors):
        super(SqueezenetDet, self).__init__()
        self.num_classes = num_classes   # we get the number of classes and anchors
        self.num_anchors = num_anchors   # from the configs file
        
        if arch == 'squeezedet':
            self.features = nn.Sequential(
                nn.Conv2d(3, 64, kernel_size=3, stride=2, padding=1),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True),
                Fire(64, 16, 64, 64),
                Fire(128, 16, 64, 64),
                nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True),
                Fire(128, 32, 128, 128),
                Fire(256, 32, 128, 128),
                nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True),
                Fire(256, 48, 192, 192),
                Fire(384, 48, 192, 192),
                Fire(384, 64, 256, 256),
                Fire(512, 64, 256, 256),
                Fire(512, 96, 384, 384),
                Fire(768, 96, 384, 384)
            )
        elif arch == 'squeezedetplus':
            self.features = nn.Sequential(
                nn.Conv2d(3, 96, kernel_size=7, stride=2, padding=3),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True),
                Fire(96, 96, 64, 64),
                Fire(128, 96, 64, 64),
                Fire(128, 192, 128, 128),
                nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True),
                Fire(256, 192, 128, 128),
                Fire(256, 288, 192, 192),
                Fire(384, 288, 192, 192),
                Fire(384, 384, 256, 256),
                nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True),
                Fire(512, 384, 256, 256),
                Fire(512, 384, 256, 256),
                Fire(512, 384, 256, 256),
            )

        else:
            raise ValueError("Unsupported SqueezeNet version")

        # adding a drop out layer, might get rid of it later on
        self.dropout = nn.Dropout(dropout_prob, inplace=True) \
            if dropout_prob > 0 else None
        self.convdet = nn.Conv2d(768 if arch == 'squeezedet' else 512,
                                 anchors_per_grid * (num_classes + 5),  # K (n_classes + 5) from the SqueezeDet paper +1 is for confidence
                                 kernel_size=3, padding=1)                      # score of how likely it is that the object exists in the box
        
        self.init_weights()

    
    
    def forward(self, x):
        x = self.features(x)
        if self.dropout is not None:
            x = self.dropout(x)
        x = self.convdet(x)
        x = x.permute(0, 2, 3, 1).contiguous()          # already doing that with transform so let's compare
        return x.view(-1, self.num_anchors, self.num_classes + 5)
        

    def init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                if m is self.convdet:
                    nn.init.normal_(m.weight, mean=0.0, std=0.002)
                else:
                    nn.init.normal_(m.weight, mean=0.0, std=0.005)
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)


class PredictionResolver(nn.Module):
    def __init__(self, input_size, num_classes, anchors, anchors_per_grid, log_softmax=False):
        super(PredictionResolver, self).__init__()
        
        self.log_softmax = log_softmax
        self.input_size = input_size
        self.num_classes = num_classes
        self.anchors = torch.from_numpy(anchors).unsqueeze(0).float()
        self.anchors_per_grid = anchors_per_grid
        
        def forward(self, pred):
            pred_class_probs = safe_softmax(pred[..., :self.num_classes].contiguous(), dim=-1)
            pred_log_class_probs = None if not self.log_softmax else \
                torch.log_softmax(pred[..., :self.num_classes].contiguous(), dim=-1)   # this would not include the +1 for C so we will
            # be fine because we will only have the number of probablities for all the classes expected
            pred_scores = torch.sigmoid(pred[..., self.num_classes:self.num_classes + 1].contiguous())
            pred_deltas = pred[..., self.num_classes + 1:].contiguous()
            pred_boxes = deltas_to_boxes(pred_deltas, self.anchors.to(pred_deltas, device),
                                         input_size=self.input_size)
            return pred_class_probs, pred_log_class_probs, pred_scores, pred_deltas, pred_boxes
    
    # We get an output of num_classes, confidence scores, and then boxes 
    
# Define the loss function next

class Loss(nn.Module):
    def __init__(self, num_anchors, class_loss_weight, positive_score_loss_weight, negative_score_loss_weight, bbox_loss_weights):
        super(Loss, self).__init__()
        self.resolver = PredictionResolver(input_size, num_classes, anchors, anchors_per_grid, log_softmax=True)
        self.num_anchors = num_anchors
        self.class_loss_weight = class_loss_weight
        self.positive_score_loss_weight = positive_score_loss_weight
        self.negative_score_loss_weight = negative_score_loss_weight
        self.bbox_loss_weight = bbox_loss_weights
        
    def forward(self, pred, gt):
        # slice the gt tensor ground truth tensor
        anchor_masks = gt[..., :1]   # for all the rows, get the first one 
        gt_boxes = gt[..., 1:5]      # the next 4 are the boxes
        gt_deltas = gt[..., 5:9]    # the next four are deltas
        gt_class_logits = gt[..., 9:]    # classification of the classes
        
        # resolver predictions
        pred_class_probs, pred_log_class_probs, pred_scores, pred_deltas, pred_boxes = self.resolver(pred)
        
        num_objects = torch.sum(anchor_masks, dim=[1,2])
        overlaps = compute_overlaps(gt_boxes, pred_boxes) * anchor_masks
        
        class_loss = torch.sum(
            self.class_loss_weight * anchor_masks * gt_class_logits * (-pred_log_class_probs),
        dim=[1,2],
        ) / num_objects
        
        positive_score_loss = torch.sum(self.position_score_loss_weight * anchor_masks * (overlaps - pred_scores) ** 2,
                                       dim=[1,2]) / num_objects
        
        negative_score_loss = torch.sum(self.negative_score_loss_weight * (1 - anchor_masks) * (overlaps - pred_scores) ** 2,
                                       dim=[1,2]) / (self.num_anchors - num_objects)
        
        
        bbox_loss = torch.sum(self.bbox_loss_weight * anchor_masks * (pred_deltas - get_deltas) ** 2,
                             dim=[1,2],) / num_objects
        
        loss = class_loss + positive_score_loss + negative_score_loss + bbox_loss
        
        loss_stat = {
            'loss': loss,
            'class_loss': class_loss,
            'score_loss': positive_score_loss + negative_score_loss,
            'bbox_loss': bbox_loss
            
        }
        return loss, loss_stat

    
class SqueezeDetWithLoss(nn.Module):
    def __init__(self, base, loss):
        super(SqueezeDetWithLoss, self).__init__()
        self.base = SqueezenetDet(arch, num_classes, num_anchors)
        self.loss = Loss(num_anchors, class_loss_weight, positive_score_loss_weight, negative_score_loss_weight, bbox_loss_weights)
            
    def forward(self, batch):
        pred = self.base(batch['image'])
        loss, loss_stats = self.loss(pred, batch['gt'])
        return loss, loss_stats

class SqueezeDet(nn.Module):
    """ Inference Model"""
    def __init__(self, base, resolver):
        super(SqueezeDet, self).__init__()
        self.base = SqueezenetDet(num_classes, num_anchors)
        self.resolver = PredictionResolver(input_size, num_classes, anchors, anchors_per_grid, log_softmax=False)
        
    def forward(self, batch):
        pred = self.base(batch['image'])
        pred_class_labels, _, pred_scores, _, pred_boxes = self.resolver(pred)
        pred_class_probs *= pred_scores
        pred_class_ids = torch.argmax(pred_class_probs, dim=2)
        pred_scores = torch.max(pred_class_probs, dim=2)[0]
        det = {'class_ids': pred_class_ids,
              'scores': pred_scores,
              'boxes': pred_boxes}
        
        return det

# %% [markdown]
# ### Dataset:
# Model has been defined but now, we can define the different parameters that go into the class

# %%
num_classes = 3
input_size = (384, 1248)
num_anchors = 
anchors
anchors_per_grid
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-57a6b3beba2c> in <module>
#       1 args = 0
# ----> 2 model = SqueezeDetWithLoss(args)
#
# <ipython-input-3-5fa4f1ca6edd> in __init__(self, args)
#     237     def __init__(self, args):
#     238         super(SqueezeDetWithLoss, self).__init__()
# --> 239         self.base = SqueezenetDet(args)
#     240         self.loss = Loss(args)
#     241
#
# <ipython-input-3-5fa4f1ca6edd> in __init__(self, args)
#      38     def __init__(self, args):
#      39         super(SqueezenetDet, self).__init__()
# ---> 40         self.num_classes = args.num_classes   # we get the number of classes and anchors
#      41         self.num_anchors = args.num_anchors   # from the configs file
#      42
#
# AttributeError: 'int' object has no attribute 'num_classes'

# %%
model = squeezenet1_1(pretrained=True)

# %%
model.eval()
# Out:
# SqueezeNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (3): Fire(
#       (squeeze): Conv2d(64, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace)
#     )
#     (4): Fire(
#       (squeeze): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace)
#     )
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (6): Fire(
#       (squeeze): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace)
#     )
#     (7): Fire(
#       (squeeze): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace)
#     )
#     (8): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (9): Fire(
#       (squeeze): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace)
#     )
#     (10): Fire(
#       (squeeze): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace)
#     )
#     (11): Fire(
#       (squeeze): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace)
#     )
#     (12): Fire(
#       (squeeze): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Conv2d(512, 1000, kernel_size=(1, 1), stride=(1, 1))
#     (2): ReLU(inplace)
#     (3): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
# )

# %%
model.classifier[1].in_channels
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-f05adddc849b> in <module>
# ----> 1 model.classifier[1].in_channels.weight
#
# AttributeError: 'int' object has no attribute 'weight'

# %%
model.features[12].expand1x1.weight
# Out:
# Parameter containing:
# tensor([[[[-0.0831]],
#
#          [[ 0.0611]],
#
#          [[-0.0077]],
#
#          ...,
#
#          [[-0.0723]],
#
#          [[-0.0063]],
#
#          [[ 0.0907]]],
#
#
#         [[[-0.0974]],
#
#          [[-0.0289]],
#
#          [[-0.0833]],
#
#          ...,
#
#          [[ 0.1137]],
#
#          [[ 0.1286]],
#
#          [[ 0.0308]]],
#
#
#         [[[-0.1306]],
#
#          [[-0.0525]],
#
#          [[ 0.1111]],
#
#          ...,
#
#          [[ 0.0274]],
#
#          [[ 0.0665]],
#
#          [[-0.0765]]],
#
#
#         ...,
#
#
#         [[[-0.2096]],
#
#          [[ 0.0899]],
#
#          [[ 0.0486]],
#
#          ...,
#
#          [[ 0.1198]],
#
#          [[ 0.1549]],
#
#          [[ 0.1210]]],
#
#
#         [[[-0.1408]],
#
#          [[-0.0767]],
#
#          [[-0.0139]],
#
#          ...,
#
#          [[-0.0415]],
#
#          [[ 0.0364]],
#
#          [[-0.1884]]],
#
#
#         [[[-0.0546]],
#
#          [[-0.0680]],
#
#          [[-0.0690]],
#
#          ...,
#
#          [[ 0.1427]],
#
#          [[-0.0874]],
#
#          [[-0.0630]]]], requires_grad=True)

# %%
model.features[12].expand3x3.weight[:1].shape
# Out:
# torch.Size([1, 64, 3, 3])

# %%
torch.cat((model.features[12].expand1x1.weight,
model.features[12].expand3x3.weight), 1)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-25-db32939b6053> in <module>
#       1 torch.cat((model.features[12].expand1x1.weight,
# ----> 2 model.features[12].expand3x3.weight), 1)
#
# RuntimeError: invalid argument 0: Sizes of tensors must match except in dimension 1. Got 1 and 3 in dimension 2 at ..\aten\src\TH/generic/THTensor.cpp:711

# %% [markdown]
# for param in model.parameters():
#     print(len(param))

# %% [markdown]
# # Note
# Look what to put in for the conv layer features from the SqueezeNet

# %%
conv8_2 = nn.Conv2d(256, 512, kernel_size=3, stride=2, padding=1)

# %%
# Don't necessarily need them 
class AuxiliaryConvolutions(nn.Module):
    """
    Additional Convolutions to produce higher-level feature maps.
    """
    def __init__(self):
        super(AuxiliaryConvolutions, self).__init__()
        self.conv8_1 = nn.Conv2d(1024, 256, kernel_size=1, padding=0)
        self.conv8_2 = nn.Conv2d(256, 512, kernel_size=3, stride=2, padding=1)

        self.conv9_1 = nn.Conv2d(512, 128, kernel_size=1, padding=0)
        self.conv9_2 = nn.Conv2d(128, 256, kernel_size=3, stride=2, padding=1)

        self.conv10_1 = nn.Conv2d(256, 128, kernel_size=1, padding=0)
        self.conv10_2 = nn.Conv2d(128, 256, kernel_size=3, padding=0)

        self.conv11_1 = nn.Conv2d(256, 128, kernel_size=1, padding=0)
        self.conv11_2 = nn.Conv2d(128, 256, kernel_size=3, padding=0)
            
            # initialize the new parameters
            
        self.init_conv2d()
    
    def init_conv2d(self):
        """
        Initialize convolution parameters
        """
        
        for c in self.children():
            if isinstance(c, nn.Conv2d):
                nn.init.xavier_uniform_(c.weight)
                nn.init.constant_(c.bias, 0.)
                
    def forward(self, conv7_feats):
        """
        Forward the new Auxiliary conv layers
        """
        x = F.relu(self.conv8_1(model_test.features[12].expand1x1.weight))
        x= F.relu(self.conv8_2(x))
        conv8_2_feats = x
        
        x = F.relu(self.conv9_1(x))
        x = F.relu(self.conv9_2(x))
        conv9_2_feats = x
        
        x = F.relu(self.conv10_1(x))
        x = F.relu(self.conv10_2(x))
        conv10_2_feats = x
        
        x = F.relu(self.conv11_1(x))
        conv11_2_feats = F.relu(self.conv11_s(x))
        
        return conv8_2_feats, conv9_2_feats, conv10_2_feats, conv11_2_feats

# %%
model_aux = AuxiliaryConvolutions()

# %%
model_aux.conv8_2
# Out:
# Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))

# %% [markdown]
# # Important Part: Prediction Convolutions
#
# Convolutions for predicting class scores nad bounding boxes

# %%
class PredictionConvolutions(nn.Module):
    """
    Convolutions to predict the class scores and bounding boxes using lower and higher-level feature maps.
    
    """
    def __init__(self, n_classes):
        """
        n_classes: Number of different types of objects
        """
        super(PredictionConvolutions, self).__init__()
        self.n_classes = n_classes 
        
        # since we want the boxes from multiple different feature maps
        # we will define the specific layers we want the boxes from
        n_boxes = {'conv8_2': 6,    # 8_2 and 9_2 are going to have 2 extra boxes with 3:1 and 1:3 aspect ratios
                   'conv9_2': 6,    # because the feature maps are huge from these layers
                   'conv10_2':4,
                   'conv11_2':4}
        
        # the four layers that we want the prior boxes from 
        # then, we are going to stack the feature maps on top of each other
        self.loc_conv8_2 = nn.Conv2d(512, n_boxes['conv8_2'] * 4, kernel_size = 3, padding=1)
        self.loc_conv9_2 = nn.Conv2d(256, n_boxes['conv9_2'] * 4, kernel_size = 3, padding =1)
        self.loc_conv10_2 = nn.Conv2d(256, n_boxes['conv10_2'] * 4, kernel_size = 3, padding =1)
        self.loc_conv11_2 = nn.Conv2d(256, n_boxes['conv11_2'] * 4, kernel_size=3, padding=1)
        
        # class probabilities predictions
        # for all the feature maps we have prior boxes for, we also want the class predictions
        self.cl_conv8_2 = nn.Conv2d(512, n_boxes['conv8_2'] * n_classes, kernel_size=3, padding=1)
        self.cl_conv9_2 = nn.Conv2d(256, n_boxes['conv9_2'] * n_classes, kernel_size=3, padding=1)
        self.cl_conv10_2 = nn.Conv2d(256, n_boxes['conv10_2'] * n_classes, kernel_size=3, padding=1)
        self.cl_conv11_2 = nn.Conv2d(256, n_boxes['conv11_2'] * n_classes, kernel_size=3, padding=1)
        
        # initialize the weights
        
        self.init_conv2d()
        
    def init_conv2d(self):
        """
        Simple function to initialize weights
        """
        for c in self.children():
            if isinstance(c, nn.Conv2d):
                nn.init.xavier_uniform_(c.weight)
                nn.init.constant_(c.bias, 0.)
                
    
    # let's define the forward functions:
    
    def forward(self, conv8_2, conv9_2, conv10_2, conv11_2):
        """
        Takes in the layers we defined in axuiliary convolutions and forwards them while getting the boxes outputs too
        
        """
        
        batch_size = conv8_2_feats.size(0)   # just taking a number from the feature map output by conv8_2 layer
        # seems like we want the number of the boxes output by the conv8_2 layer to be the same 
        
        # let's start with the first layer of the auxiliary convolutions:
        
        # perform the convolution on the feature map of the layer conv8_2 and get the output
        l_conv8_2 = self.loc_conv8_2(conv8_2_feats)    # Outputs: (N, 24, 10, 10)
        # now transform that output to be the same as prior-box order:
        # permute just switches the location of values in the tensor
        l_conv8_2 = l_conv8_2.permute(0, 2, 3, 1).contiguous() # (N, 10, 10, 24)
        # .contiguous()Returns a contiguous in memory tensor containing the same data as self tensor. 
        # If self tensor is already in the specified memory format, this function returns the self tensor.
        l_conv8_2 = l_conv8_2.view(batch_size, -1, 4) # 
        
        l_conv9_2 = self.loc_conv8_2(conv9_2_feats)    # Outputs: (N, 24, 10, 10)
        l_conv9_2 = l_conv9_2.permute(0, 2, 3, 1).contiguous() # (N, 10, 10, 24)
        l_conv9_2 = l_conv9_2.view(batch_size, -1, 4) # (N, 150, 4)
        
        l_conv10_2 = self.loc_conv8_2(conv10_2_feats)    # Outputs: (N, 24, 10, 10)
        l_conv10_2 = l_conv10_2.permute(0, 2, 3, 1).contiguous() # (N, 10, 10, 24)
        l_conv10_2 = l_conv10_2.view(batch_size, -1, 4) # (N, 36, 4)
        
        l_conv11_2 = self.loc_conv8_2(conv11_2_feats)    # Outputs: (N, 24, 10, 10)
        l_conv11_2 = l_conv11_2.permute(0, 2, 3, 1).contiguous() # (N, 10, 10, 24)
        l_conv11_2 = l_conv11_2.view(batch_size, -1, 4) # (N, 4, 4)
        
        # Classification
        # Predict classes for boxes i.e. Classification
        c_conv8_2 = self.cl_conv8_2(conv8_2_feats)
        c_conv8_2 = c_conv8_2.permute(0, 2, 3, 1).contiguous()
        c_conv8_2 = c_conv8_2.view(batch_size, -1, self.n_classes)
        
        c_conv9_2 = self.cl_conv9_2(conv9_2_feats)
        c_conv9_2 = c_conv9_2.permute(0, 2, 3, 1).contiguous()
        c_conv9_2 = c_conv9_2.view(batch_size, -1, self.n_classes)
        
        c_conv10_2 = self.cl_conv10_2(conv10_2_feats)
        c_conv10_2 = c_conv10_2.permute(0, 2, 3, 1).contiguous()
        c_conv10_2 = c_conv10_2.view(batch_size, -1, self.n_classes)
        
        c_conv11_2 = self.cl_conv11_2(conv11_2_feats)
        c_conv11_2 = c_conv11_2.permute(0, 2, 3, 1).contiguous()
        c_conv11_2 = c_conv11_2.view(batch_size, -1, self.n_classes)
        
        locs = torch.cat([l_conv8_2, l_conv9_2, l_conv10_2, l_conv11_2], dim=1)
        class_scores = torch.cat([c_conv8_2, c_conv9_2, c_conv10_2, c_conv11_2])
        
        return locs, class_scores

# %% [markdown]
# ### Now comes the fun part where we try to get the network put together

# %%
class Squeeze_detect(nn.Module):
    """
    squeeze_detect network that encapsulates the base Squeezenet, auxiliary and prediction convs
    """
    def __init__(self, n_classes):
        super(Squeeze_detect, self).__init__()
        self.n_classes = n_classes
        
        self.base = SqueezeNet()
        self.aux_convs = AuxiliaryConvolutions()
        self.pred_convs = PredictionConvolutions(n_classes)
        
        self.rescale_factors = nn.Parameter(torch.FloatTensor(1, 512, 1, 1))    # there are 512 channels in 8_2 
        nn.init.constant_(self.rescale_factors, 20)
        
        # prior boxes 
        self.prior_cxcy = self.create_prior_boxes()
        
    def forward(self, image):
        """
        Forward Propagation.
        """
        
        # Do not need to do these because we are not really retraining stuff from squeezenet
       # conv8_2_feats = self.base(image)
        
        # rescale the conv8_2 after L2 norm
       # norm = conv8_2_feats.pow(2).sum(dim=1, keepdim=True).sqrt()
        # conv8_2_feats = conv8_2_feats / norm
        # conv8_2_feats = conv8_3_feats * self.rescale_factors
        
        # Auxiliary
        # higher level feature map generators
        # HERE it would be something like SqueezeNet.features[12].expand1x1.weights?
        conv8_2_feats, conv9_2_feats, conv10_2_feats, conv11_2_feats = self.aux_convs(conv7_feats)
        
        # run prediction convolutions
        locs, classes_scores = self.pred_convs(conv8_2_feats, conv9_2_feats, conv10_2_feats, conv11_2_feats)
        
        return locs, class_scores
    
    def create_prior_boxes(self):
        """
        create the ~ 8K numbers of priors but they would be less because we have less layers that we are doing
        calcs on
        """
        
        # the feature map dimensions for each layer, we want the end 
        fmap_dims = {'conv8_2': 10,
                     'conv9_2':5,
                     'conv10_2':3,
                     'conv11_2':1
                    }
    
        obj_scales = {'conv8_2':0.375,
                      'conv9_2':0.55,
                      'conv10_2':0.725,
                      'conv11_2':0.9                     
                     }
        aspect_ratios = {'conv8_2': [1., 2., 3., 0.5, .333],
                         'conv9_2':[1., 2., 3., 0.5, .333],
                         'conv10_2':[1., 2., 0.5],
                         'conv11_2':[1., 2., 0.5]}
    
        
        fmaps = list(fmap_dims.keys())
        
        prior_boxes = []
        
        for k, fmap in enumerate(fmaps):
            for i in range(fmaps_dims[fmap]):
                for j in range(fmaps_dims[fmap]):
                    cx = (j + 0.5) / fmap_dims[fmap]
                    cy = (i + 0.5) / fmap_dims[fmap]
                    
                    for ratio in aspect_ratios[fmap]:
                        prior_boxes.append([cx, cy, obj_scales[fmap] * sqrt(ratio), obj_scales[fmap] /sqrt(ratio)])
                        
                        if ratio == 1:
                            try:
                                additional_scale = sqrt(obj_scales[fmap] * obj_scales[fmaps[k+1]])
                                
                            except:
                                additional_scale = 1.
                                prior_boxes.append([cx, cy, additional_scale, additional_scale])
                                
        prior_boxes = torch.FloatTensor(prior_boxes).to(device)
        prior_boxes.clamp_(0, 1)
        
        return prior_boxes
    
    
    def detect_objects(self, predicted_loss, predicted_scores, min_sccore, max_overlap, top_k):
        """
        
        """
        
        pass

# %%
        fmap_dims = {'conv8_2': 10,
                     'conv9_2':5,
                     'conv10_2':3,
                     'conv11_2':1
                    }

# %%
    fmaps = list(fmap_dims.keys())

# %%
for k, fmap in enumerate(fmaps):
    print(k)
    print(fmap)
# Out:
# 0
# conv8_2
# 1
# conv9_2
# 2
# conv10_2
# 3
# conv11_2

# %%
cl = PredictionConvolutions(10)

# %% [markdown]
# If we put nn.ReLU in between the conv layers, we would call on nn.Module and type:
# nn.ReLU(inplace=True)
#
# BUT if we put in the forward function, we would call on the ReLU function directly and

# %%
model.load_state_dict(torch.load('squeezenet1_0-a815701f.pth'))
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
model.eval()
# Out:
# SqueezeNet(
#   (features): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(7, 7), stride=(2, 2))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (3): Fire(
#       (squeeze): Conv2d(96, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace)
#     )
#     (4): Fire(
#       (squeeze): Conv2d(128, 16, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace)
#       (expand1x1): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace)
#       (expand3x3): Conv2d(16, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace)
#     )
#     (5): Fire(
#       (squeeze): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace)
#     )
#     (6): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (7): Fire(
#       (squeeze): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace)
#       (expand1x1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace)
#       (expand3x3): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace)
#     )
#     (8): Fire(
#       (squeeze): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace)
#     )
#     (9): Fire(
#       (squeeze): Conv2d(384, 48, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace)
#       (expand1x1): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace)
#       (expand3x3): Conv2d(48, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace)
#     )
#     (10): Fire(
#       (squeeze): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace)
#     )
#     (11): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (12): Fire(
#       (squeeze): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#       (squeeze_activation): ReLU(inplace)
#       (expand1x1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#       (expand1x1_activation): ReLU(inplace)
#       (expand3x3): Conv2d(64, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (expand3x3_activation): ReLU(inplace)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Conv2d(512, 1000, kernel_size=(1, 1), stride=(1, 1))
#     (2): ReLU(inplace)
#     (3): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
# )

# %% [markdown]
# # DETR model head

# %% [markdown]
# After the squeezenet backbone, passing the image through the CNN, we pass in the feature pyramid to transformer encoder-decoder, which outputs a box of predictions:
#
# 1. CNN Backbone:
#     - Input: Image
#     - Output: Feature maps with multiple channels that are flattened to be passed into the encoder
# 2. Transformer encoder-decoder:
#     - Encoder takes in the flattened layer and outputs the same size shape sequence.
#     - Decoder takes in the output from the encoder but also takes in Object Queries
#     #### Object Queries
#         - Big N, represents the output we want i.e. if 4 tuples for 4 objects and their bounding boxes, we get that.
#         - Each object query vector wouldask the image different questions like what is in your right box, left box, lower left box, lower right box.
# 3. Feed Forwad Network (FFN):
